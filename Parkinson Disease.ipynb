# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Parkinsson disease.csv')

# %%
df
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0    phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1    phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2    phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3    phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4    phon_R01_S01_5      116.014       141.781       110.655         0.01284
# ..              ...          ...           ...           ...             ...
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1             0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2             0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3             0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4             0.00011   0.00655   0.00908     0.01966       0.06425  ...
# ..                ...       ...       ...         ...           ...  ...
# 190           0.00003   0.00263   0.00259     0.00790       0.04087  ...
# 191           0.00003   0.00331   0.00292     0.00994       0.02751  ...
# 192           0.00008   0.00624   0.00564     0.01873       0.02308  ...
# 193           0.00004   0.00370   0.00390     0.01109       0.02296  ...
# 194           0.00003   0.00295   0.00317     0.00885       0.01884  ...
#
#      Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# 0        0.06545  0.02211  21.033       1  0.414783  0.815285 -4.813031
# 1        0.09403  0.01929  19.085       1  0.458359  0.819521 -4.075192
# 2        0.08270  0.01309  20.651       1  0.429895  0.825288 -4.443179
# 3        0.08771  0.01353  20.644       1  0.434969  0.819235 -4.117501
# 4        0.10470  0.01767  19.649       1  0.417356  0.823484 -3.747787
# ..           ...      ...     ...     ...       ...       ...       ...
# 190      0.07008  0.02764  19.517       0  0.448439  0.657899 -6.538586
# 191      0.04812  0.01810  19.147       0  0.431674  0.683244 -6.195325
# 192      0.03804  0.10715  17.883       0  0.407567  0.655683 -6.787197
# 193      0.03794  0.07223  19.020       0  0.451221  0.643956 -6.744577
# 194      0.03078  0.04398  21.209       0  0.462803  0.664357 -5.724056
#
#       spread2        D2       PPE
# 0    0.266482  2.301442  0.284654
# 1    0.335590  2.486855  0.368674
# 2    0.311173  2.342259  0.332634
# 3    0.334147  2.405554  0.368975
# 4    0.234513  2.332180  0.410335
# ..        ...       ...       ...
# 190  0.121952  2.657476  0.133050
# 191  0.129303  2.784312  0.168895
# 192  0.158453  2.679772  0.131728
# 193  0.207454  2.138608  0.123306
# 194  0.190667  2.555477  0.148569
#
# [195 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
#  16  HNR               195 non-null    float64
#  17  status            195 non-null    int64
#  18  RPDE              195 non-null    float64
#  19  DFA               195 non-null    float64
#  20  spread1           195 non-null    float64
#  21  spread2           195 non-null    float64
#  22  D2                195 non-null    float64
#  23  PPE               195 non-null    float64
# dtypes: float64(22), int64(1), object(1)
# memory usage: 36.7+ KB

# %%
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# 25%            0.000020    0.001660    0.001860    0.004985      0.016505
# 50%            0.000030    0.002500    0.002690    0.007490      0.022970
# 75%            0.000060    0.003835    0.003955    0.011505      0.037885
# max            0.000260    0.021440    0.019580    0.064330      0.119080
#
#        MDVP:Shimmer(dB)  ...  Shimmer:DDA         NHR         HNR      status  \
# count        195.000000  ...   195.000000  195.000000  195.000000  195.000000
# mean           0.282251  ...     0.046993    0.024847   21.885974    0.753846
# std            0.194877  ...     0.030459    0.040418    4.425764    0.431878
# min            0.085000  ...     0.013640    0.000650    8.441000    0.000000
# 25%            0.148500  ...     0.024735    0.005925   19.198000    1.000000
# 50%            0.221000  ...     0.038360    0.011660   22.085000    1.000000
# 75%            0.350000  ...     0.060795    0.025640   25.075500    1.000000
# max            1.302000  ...     0.169420    0.314820   33.047000    1.000000
#
#              RPDE         DFA     spread1     spread2          D2         PPE
# count  195.000000  195.000000  195.000000  195.000000  195.000000  195.000000
# mean     0.498536    0.718099   -5.684397    0.226510    2.381826    0.206552
# std      0.103942    0.055336    1.090208    0.083406    0.382799    0.090119
# min      0.256570    0.574282   -7.964984    0.006274    1.423287    0.044539
# 25%      0.421306    0.674758   -6.450096    0.174351    2.099125    0.137451
# 50%      0.495954    0.722254   -5.720868    0.218885    2.361532    0.194052
# 75%      0.587562    0.761881   -5.046192    0.279234    2.636456    0.252980
# max      0.685151    0.825288   -2.434031    0.450493    3.671155    0.527367
#
# [8 rows x 23 columns]

# %%
df.corr()
# Out:
#                   MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# MDVP:Fo(Hz)          1.000000      0.400985      0.596546       -0.118003
# MDVP:Fhi(Hz)         0.400985      1.000000      0.084951        0.102086
# MDVP:Flo(Hz)         0.596546      0.084951      1.000000       -0.139919
# MDVP:Jitter(%)      -0.118003      0.102086     -0.139919        1.000000
# MDVP:Jitter(Abs)    -0.382027     -0.029198     -0.277815        0.935714
# MDVP:RAP            -0.076194      0.097177     -0.100519        0.990276
# MDVP:PPQ            -0.112165      0.091126     -0.095828        0.974256
# Jitter:DDP          -0.076213      0.097150     -0.100488        0.990276
# MDVP:Shimmer        -0.098374      0.002281     -0.144543        0.769063
# MDVP:Shimmer(dB)    -0.073742      0.043465     -0.119089        0.804289
# Shimmer:APQ3        -0.094717     -0.003743     -0.150747        0.746625
# Shimmer:APQ5        -0.070682     -0.009997     -0.101095        0.725561
# MDVP:APQ            -0.077774      0.004937     -0.107293        0.758255
# Shimmer:DDA         -0.094732     -0.003733     -0.150737        0.746635
# NHR                 -0.021981      0.163766     -0.108670        0.906959
# HNR                  0.059144     -0.024893      0.210851       -0.728165
# status              -0.383535     -0.166136     -0.380200        0.278220
# RPDE                -0.383894     -0.112404     -0.400143        0.360673
# DFA                 -0.446013     -0.343097     -0.050406        0.098572
# spread1             -0.413738     -0.076658     -0.394857        0.693577
# spread2             -0.249450     -0.002954     -0.243829        0.385123
# D2                   0.177980      0.176323     -0.100629        0.433434
# PPE                 -0.372356     -0.069543     -0.340071        0.721543
#
#                   MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  \
# MDVP:Fo(Hz)              -0.382027 -0.076194 -0.112165   -0.076213
# MDVP:Fhi(Hz)             -0.029198  0.097177  0.091126    0.097150
# MDVP:Flo(Hz)             -0.277815 -0.100519 -0.095828   -0.100488
# MDVP:Jitter(%)            0.935714  0.990276  0.974256    0.990276
# MDVP:Jitter(Abs)          1.000000  0.922911  0.897778    0.922913
# MDVP:RAP                  0.922911  1.000000  0.957317    1.000000
# MDVP:PPQ                  0.897778  0.957317  1.000000    0.957319
# Jitter:DDP                0.922913  1.000000  0.957319    1.000000
# MDVP:Shimmer              0.703322  0.759581  0.797826    0.759555
# MDVP:Shimmer(dB)          0.716601  0.790652  0.839239    0.790621
# Shimmer:APQ3              0.697153  0.744912  0.763580    0.744894
# Shimmer:APQ5              0.648961  0.709927  0.786780    0.709907
# MDVP:APQ                  0.648793  0.737455  0.804139    0.737439
# Shimmer:DDA               0.697170  0.744919  0.763592    0.744901
# NHR                       0.834972  0.919521  0.844604    0.919548
# HNR                      -0.656810 -0.721543 -0.731510   -0.721494
# status                    0.338653  0.266668  0.288698    0.266646
# RPDE                      0.441839  0.342140  0.333274    0.342079
# DFA                       0.175036  0.064083  0.196301    0.064026
# spread1                   0.735779  0.648328  0.716489    0.648328
# spread2                   0.388543  0.324407  0.407605    0.324377
# D2                        0.310694  0.426605  0.412524    0.426556
# PPE                       0.748162  0.670999  0.769647    0.671005
#
#                   MDVP:Shimmer  MDVP:Shimmer(dB)  ...  Shimmer:DDA       NHR  \
# MDVP:Fo(Hz)          -0.098374         -0.073742  ...    -0.094732 -0.021981
# MDVP:Fhi(Hz)          0.002281          0.043465  ...    -0.003733  0.163766
# MDVP:Flo(Hz)         -0.144543         -0.119089  ...    -0.150737 -0.108670
# MDVP:Jitter(%)        0.769063          0.804289  ...     0.746635  0.906959
# MDVP:Jitter(Abs)      0.703322          0.716601  ...     0.697170  0.834972
# MDVP:RAP              0.759581          0.790652  ...     0.744919  0.919521
# MDVP:PPQ              0.797826          0.839239  ...     0.763592  0.844604
# Jitter:DDP            0.759555          0.790621  ...     0.744901  0.919548
# MDVP:Shimmer          1.000000          0.987258  ...     0.987626  0.722194
# MDVP:Shimmer(dB)      0.987258          1.000000  ...     0.963202  0.744477
# Shimmer:APQ3          0.987625          0.963198  ...     1.000000  0.716207
# Shimmer:APQ5          0.982835          0.973751  ...     0.960072  0.658080
# MDVP:APQ              0.950083          0.960977  ...     0.896647  0.694019
# Shimmer:DDA           0.987626          0.963202  ...     1.000000  0.716215
# NHR                   0.722194          0.744477  ...     0.716215  1.000000
# HNR                  -0.835271         -0.827805  ...    -0.827130 -0.714072
# status                0.367430          0.350697  ...     0.347608  0.189429
# RPDE                  0.447424          0.410684  ...     0.435237  0.370890
# DFA                   0.159954          0.165157  ...     0.151132 -0.131882
# spread1               0.654734          0.652547  ...     0.610971  0.540865
# spread2               0.452025          0.454314  ...     0.402223  0.318099
# D2                    0.507088          0.512233  ...     0.467261  0.470949
# PPE                   0.693771          0.695058  ...     0.645389  0.552591
#
#                        HNR    status      RPDE       DFA   spread1   spread2  \
# MDVP:Fo(Hz)       0.059144 -0.383535 -0.383894 -0.446013 -0.413738 -0.249450
# MDVP:Fhi(Hz)     -0.024893 -0.166136 -0.112404 -0.343097 -0.076658 -0.002954
# MDVP:Flo(Hz)      0.210851 -0.380200 -0.400143 -0.050406 -0.394857 -0.243829
# MDVP:Jitter(%)   -0.728165  0.278220  0.360673  0.098572  0.693577  0.385123
# MDVP:Jitter(Abs) -0.656810  0.338653  0.441839  0.175036  0.735779  0.388543
# MDVP:RAP         -0.721543  0.266668  0.342140  0.064083  0.648328  0.324407
# MDVP:PPQ         -0.731510  0.288698  0.333274  0.196301  0.716489  0.407605
# Jitter:DDP       -0.721494  0.266646  0.342079  0.064026  0.648328  0.324377
# MDVP:Shimmer     -0.835271  0.367430  0.447424  0.159954  0.654734  0.452025
# MDVP:Shimmer(dB) -0.827805  0.350697  0.410684  0.165157  0.652547  0.454314
# Shimmer:APQ3     -0.827123  0.347617  0.435242  0.151124  0.610967  0.402243
# Shimmer:APQ5     -0.813753  0.351148  0.399903  0.213873  0.646809  0.457195
# MDVP:APQ         -0.800407  0.364316  0.451379  0.157276  0.673158  0.502188
# Shimmer:DDA      -0.827130  0.347608  0.435237  0.151132  0.610971  0.402223
# NHR              -0.714072  0.189429  0.370890 -0.131882  0.540865  0.318099
# HNR               1.000000 -0.361515 -0.598736 -0.008665 -0.673210 -0.431564
# status           -0.361515  1.000000  0.308567  0.231739  0.564838  0.454842
# RPDE             -0.598736  0.308567  1.000000 -0.110950  0.591117  0.479905
# DFA              -0.008665  0.231739 -0.110950  1.000000  0.195668  0.166548
# spread1          -0.673210  0.564838  0.591117  0.195668  1.000000  0.652358
# spread2          -0.431564  0.454842  0.479905  0.166548  0.652358  1.000000
# D2               -0.601401  0.340232  0.236931 -0.165381  0.495123  0.523532
# PPE              -0.692876  0.531039  0.545886  0.270445  0.962435  0.644711
#
#                         D2       PPE
# MDVP:Fo(Hz)       0.177980 -0.372356
# MDVP:Fhi(Hz)      0.176323 -0.069543
# MDVP:Flo(Hz)     -0.100629 -0.340071
# MDVP:Jitter(%)    0.433434  0.721543
# MDVP:Jitter(Abs)  0.310694  0.748162
# MDVP:RAP          0.426605  0.670999
# MDVP:PPQ          0.412524  0.769647
# Jitter:DDP        0.426556  0.671005
# MDVP:Shimmer      0.507088  0.693771
# MDVP:Shimmer(dB)  0.512233  0.695058
# Shimmer:APQ3      0.467265  0.645377
# Shimmer:APQ5      0.502174  0.702456
# MDVP:APQ          0.536869  0.721694
# Shimmer:DDA       0.467261  0.645389
# NHR               0.470949  0.552591
# HNR              -0.601401 -0.692876
# status            0.340232  0.531039
# RPDE              0.236931  0.545886
# DFA              -0.165381  0.270445
# spread1           0.495123  0.962435
# spread2           0.523532  0.644711
# D2                1.000000  0.480585
# PPE               0.480585  1.000000
#
# [23 rows x 23 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.isnull().sum()#So we can see that dataset doesn't contain the null values
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# ### Numerical Features

# %%
numerical_features=[feature for feature in df.columns if df[feature].dtype!='O']

# %%
numerical_features
# Out:
# ['MDVP:Fo(Hz)',
#  'MDVP:Fhi(Hz)',
#  'MDVP:Flo(Hz)',
#  'MDVP:Jitter(%)',
#  'MDVP:Jitter(Abs)',
#  'MDVP:RAP',
#  'MDVP:PPQ',
#  'Jitter:DDP',
#  'MDVP:Shimmer',
#  'MDVP:Shimmer(dB)',
#  'Shimmer:APQ3',
#  'Shimmer:APQ5',
#  'MDVP:APQ',
#  'Shimmer:DDA',
#  'NHR',
#  'HNR',
#  'status',
#  'RPDE',
#  'DFA',
#  'spread1',
#  'spread2',
#  'D2',
#  'PPE']

# %% [markdown]
# ### Discrete Features

# %%
discrete_features=[feature for feature in numerical_features if len(df[feature].unique())<25]

# %%
discrete_features
# Out:
# ['MDVP:Jitter(Abs)', 'status']

# %% [markdown]
# ### Continuous Features

# %%
continuous_features=[feature for feature in numerical_features if feature not in discrete_features]

# %%
continuous_features
# Out:
# ['MDVP:Fo(Hz)',
#  'MDVP:Fhi(Hz)',
#  'MDVP:Flo(Hz)',
#  'MDVP:Jitter(%)',
#  'MDVP:RAP',
#  'MDVP:PPQ',
#  'Jitter:DDP',
#  'MDVP:Shimmer',
#  'MDVP:Shimmer(dB)',
#  'Shimmer:APQ3',
#  'Shimmer:APQ5',
#  'MDVP:APQ',
#  'Shimmer:DDA',
#  'NHR',
#  'HNR',
#  'RPDE',
#  'DFA',
#  'spread1',
#  'spread2',
#  'D2',
#  'PPE']

# %%
for feature in continuous_features:
    df[feature].hist(bins=25)
    plt.xlabel(feature)
    plt.ylabel('count')
    plt.show()

# %% [markdown]
# ### Outliers

# %%
for feature in continuous_features:
    sns.boxplot(df[feature])
    plt.show()
# Out:
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Categorical Features

# %%
categorical_features=[feature for feature in df.columns if df[feature].dtype=='O']

# %%
categorical_features
# Out:
# ['name']

# %% [markdown]
# # Feature Engineering

# %%
df.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %% [markdown]
# we can see that we don't have any null values present in the dataset

# %%
#as we can see that name feature is not important in the dataset so remove that.
df=df.drop(['name'],axis=1)

# %%
df
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819         0.00968
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# 2             0.00009   0.00544   0.00781     0.01633       0.05233
# 3             0.00009   0.00502   0.00698     0.01505       0.05492
# 4             0.00011   0.00655   0.00908     0.01966       0.06425
# ..                ...       ...       ...         ...           ...
# 190           0.00003   0.00263   0.00259     0.00790       0.04087
# 191           0.00003   0.00331   0.00292     0.00994       0.02751
# 192           0.00008   0.00624   0.00564     0.01873       0.02308
# 193           0.00004   0.00370   0.00390     0.01109       0.02296
# 194           0.00003   0.00295   0.00317     0.00885       0.01884
#
#      MDVP:Shimmer(dB)  ...  Shimmer:DDA      NHR     HNR  status      RPDE  \
# 0               0.426  ...      0.06545  0.02211  21.033       1  0.414783
# 1               0.626  ...      0.09403  0.01929  19.085       1  0.458359
# 2               0.482  ...      0.08270  0.01309  20.651       1  0.429895
# 3               0.517  ...      0.08771  0.01353  20.644       1  0.434969
# 4               0.584  ...      0.10470  0.01767  19.649       1  0.417356
# ..                ...  ...          ...      ...     ...     ...       ...
# 190             0.405  ...      0.07008  0.02764  19.517       0  0.448439
# 191             0.263  ...      0.04812  0.01810  19.147       0  0.431674
# 192             0.256  ...      0.03804  0.10715  17.883       0  0.407567
# 193             0.241  ...      0.03794  0.07223  19.020       0  0.451221
# 194             0.190  ...      0.03078  0.04398  21.209       0  0.462803
#
#           DFA   spread1   spread2        D2       PPE
# 0    0.815285 -4.813031  0.266482  2.301442  0.284654
# 1    0.819521 -4.075192  0.335590  2.486855  0.368674
# 2    0.825288 -4.443179  0.311173  2.342259  0.332634
# 3    0.819235 -4.117501  0.334147  2.405554  0.368975
# 4    0.823484 -3.747787  0.234513  2.332180  0.410335
# ..        ...       ...       ...       ...       ...
# 190  0.657899 -6.538586  0.121952  2.657476  0.133050
# 191  0.683244 -6.195325  0.129303  2.784312  0.168895
# 192  0.655683 -6.787197  0.158453  2.679772  0.131728
# 193  0.643956 -6.744577  0.207454  2.138608  0.123306
# 194  0.664357 -5.724056  0.190667  2.555477  0.148569
#
# [195 rows x 23 columns]

# %%
#Let's handle the outliers
for feature in continuous_features:
    IQR=df[feature].quantile(0.75)-df[feature].quantile(0.25)
    print(feature,"details")
    print(IQR)
    lower_bridge=df[feature].quantile(0.25)-IQR*3
    print(lower_bridge)
    upper_bridge=df[feature].quantile(0.75)+IQR*3
    print(upper_bridge)
    df.loc[df[feature]>=upper_bridge,feature]=upper_bridge
    df.loc[df[feature]<lower_bridge,feature]=lower_bridge
# Out:
# MDVP:Fo(Hz) details
# 65.197
# -78.019
# 378.36
# MDVP:Fhi(Hz) details
# 89.34299999999999
# -133.16649999999998
# 492.2345
# MDVP:Flo(Hz) details
# 55.72750000000002
# -82.89150000000006
# 307.2010000000001
# MDVP:Jitter(%) details
# 0.003905
# -0.008255
# 0.01908
# MDVP:RAP details
# 0.002175
# -0.0048649999999999995
# 0.01036
# MDVP:PPQ details
# 0.002095
# -0.004425
# 0.01024
# Jitter:DDP details
# 0.0065200000000000015
# -0.014575000000000005
# 0.031065000000000006
# MDVP:Shimmer details
# 0.021380000000000003
# -0.047635000000000004
# 0.102025
# MDVP:Shimmer(dB) details
# 0.20149999999999998
# -0.45599999999999996
# 0.9544999999999999
# Shimmer:APQ3 details
# 0.012019999999999998
# -0.027814999999999993
# 0.05632499999999999
# Shimmer:APQ5 details
# 0.0128
# -0.028820000000000005
# 0.06078
# MDVP:APQ details
# 0.01632
# -0.03588
# 0.07836
# Shimmer:DDA details
# 0.03606
# -0.08344499999999999
# 0.168975
# NHR details
# 0.019715
# -0.05322
# 0.084785
# HNR details
# 5.877499999999998
# 1.5655000000000072
# 42.70799999999999
# RPDE details
# 0.16625649999999997
# -0.07746349999999991
# 1.0863319999999999
# DFA details
# 0.08712399999999998
# 0.4133855000000001
# 1.0232535
# spread1 details
# 1.4039040000000007
# -10.661808000000002
# -0.8344799999999974
# spread2 details
# 0.10488349999999996
# -0.14029999999999987
# 0.5938844999999999
# D2 details
# 0.5373304999999999
# 0.4871340000000002
# 4.248447499999999
# PPE details
# 0.11552899999999999
# -0.209136
# 0.599567

# %%
for feature in continuous_features:
    df[feature].hist(bins=25)
    plt.xlabel(feature)
    plt.ylabel('count')
    plt.show()

# %%
for feature in continuous_features:
    sns.boxplot(df[feature])
    plt.show()
# Out:
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\wwwka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
X=df.drop(labels=['status'],axis=1)
y=df['status']

# %%
X
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997        0.007840
# 1        122.400       148.650       113.819        0.009680
# 2        116.682       131.111       111.555        0.010500
# 3        116.676       137.871       111.366        0.009970
# 4        116.014       141.781       110.655        0.012840
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261        0.004590
# 191      209.516       253.017        89.488        0.005640
# 192      174.688       240.005        74.287        0.013222
# 193      198.764       358.220        74.904        0.007400
# 194      214.289       260.277        77.973        0.005670
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370  0.005540     0.01109       0.04374
# 1             0.00008   0.00465  0.006960     0.01394       0.06134
# 2             0.00009   0.00544  0.007098     0.01633       0.05233
# 3             0.00009   0.00502  0.006980     0.01505       0.05492
# 4             0.00011   0.00655  0.007098     0.01966       0.06425
# ..                ...       ...       ...         ...           ...
# 190           0.00003   0.00263  0.002590     0.00790       0.04087
# 191           0.00003   0.00331  0.002920     0.00994       0.02751
# 192           0.00008   0.00624  0.005640     0.01873       0.02308
# 193           0.00004   0.00370  0.003900     0.01109       0.02296
# 194           0.00003   0.00295  0.003170     0.00885       0.01884
#
#      MDVP:Shimmer(dB)  ...  MDVP:APQ  Shimmer:DDA       NHR     HNR      RPDE  \
# 0               0.426  ...   0.02971      0.06545  0.022110  21.033  0.414783
# 1               0.626  ...   0.04368      0.09403  0.019290  19.085  0.458359
# 2               0.482  ...   0.03590      0.08270  0.013090  20.651  0.429895
# 3               0.517  ...   0.03772      0.08771  0.013530  20.644  0.434969
# 4               0.584  ...   0.04465      0.10470  0.017670  19.649  0.417356
# ..                ...  ...       ...          ...       ...     ...       ...
# 190             0.405  ...   0.02745      0.07008  0.027640  19.517  0.448439
# 191             0.263  ...   0.01879      0.04812  0.018100  19.147  0.431674
# 192             0.256  ...   0.01667      0.03804  0.055212  17.883  0.407567
# 193             0.241  ...   0.01588      0.03794  0.055212  19.020  0.451221
# 194             0.190  ...   0.01373      0.03078  0.043980  21.209  0.462803
#
#           DFA   spread1   spread2        D2       PPE
# 0    0.815285 -4.813031  0.266482  2.301442  0.284654
# 1    0.819521 -4.075192  0.335590  2.486855  0.368674
# 2    0.825288 -4.443179  0.311173  2.342259  0.332634
# 3    0.819235 -4.117501  0.334147  2.405554  0.368975
# 4    0.823484 -3.747787  0.234513  2.332180  0.410335
# ..        ...       ...       ...       ...       ...
# 190  0.657899 -6.538586  0.121952  2.657476  0.133050
# 191  0.683244 -6.195325  0.129303  2.784312  0.168895
# 192  0.655683 -6.787197  0.158453  2.679772  0.131728
# 193  0.643956 -6.744577  0.207454  2.138608  0.123306
# 194  0.664357 -5.724056  0.190667  2.555477  0.148569
#
# [195 rows x 22 columns]

# %%
plt.figure(figsize=(20,20))
sns.heatmap(X.corr(),annot=True)
plt.show()

# %%
# With the following function we can select highly correlated features
#It will remove the first features that is correlated with anything other feature
def correlation(dataset,threshold):
    col_corr=set()
    corr_matrix=df.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j])>threshold:#we are interested in absolute coefficient value
                colname=corr_matrix.columns[i]#getting the name of the column
                col_corr.add(colname)
    return col_corr

# %%
corr_features=correlation(X,0.7)
print(corr_features)
len(set(corr_features))
# Out:
# {'Shimmer:APQ5', 'MDVP:PPQ', 'HNR', 'MDVP:Shimmer(dB)', 'MDVP:Jitter(Abs)', 'NHR', 'spread1', 'Shimmer:APQ3', 'MDVP:RAP', 'MDVP:Shimmer', 'PPE', 'Shimmer:DDA', 'Jitter:DDP', 'MDVP:APQ'}
# 14

# %%
X=X.drop(corr_features,axis=1)

# %%
X
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)      RPDE  \
# 0        119.992       157.302        74.997        0.007840  0.414783
# 1        122.400       148.650       113.819        0.009680  0.458359
# 2        116.682       131.111       111.555        0.010500  0.429895
# 3        116.676       137.871       111.366        0.009970  0.434969
# 4        116.014       141.781       110.655        0.012840  0.417356
# ..           ...           ...           ...             ...       ...
# 190      174.188       230.978        94.261        0.004590  0.448439
# 191      209.516       253.017        89.488        0.005640  0.431674
# 192      174.688       240.005        74.287        0.013222  0.407567
# 193      198.764       358.220        74.904        0.007400  0.451221
# 194      214.289       260.277        77.973        0.005670  0.462803
#
#           DFA   spread2        D2
# 0    0.815285  0.266482  2.301442
# 1    0.819521  0.335590  2.486855
# 2    0.825288  0.311173  2.342259
# 3    0.819235  0.334147  2.405554
# 4    0.823484  0.234513  2.332180
# ..        ...       ...       ...
# 190  0.657899  0.121952  2.657476
# 191  0.683244  0.129303  2.784312
# 192  0.655683  0.158453  2.679772
# 193  0.643956  0.207454  2.138608
# 194  0.664357  0.190667  2.555477
#
# [195 rows x 8 columns]

# %%
plt.figure(figsize=(15,15))
sns.heatmap(X.corr(),annot=True)
plt.show()

# %%
# Important feature using ExtraTreesRegressor
from sklearn.ensemble import ExtraTreesRegressor
selection=ExtraTreesRegressor()
selection.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
#plot graph of feature importances for better visualization
plt.figure(figsize=(12,8))
feat_importances=pd.Series(selection.feature_importances_,index=X.columns)
feat_importances.nlargest(20).plot(kind='barh')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (136, 8) (59, 8) (136,) (59,)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier()

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rf.score(X_train,y_train)
# Out:
# 1.0

# %%
rf.score(X_test,y_test)
# Out:
# 0.9830508474576272

# %%
y_pred=rf.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92        13
#            1       0.98      0.98      0.98        46
#
#     accuracy                           0.97        59
#    macro avg       0.95      0.95      0.95        59
# weighted avg       0.97      0.97      0.97        59

# %%
print(confusion_matrix(y_pred,y_test))
# Out:
# [[12  1]
#  [ 1 45]]

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(X_train,y_train)
# Out:
# 0.8382352941176471

# %%
lr.score(X_test,y_test)
# Out:
# 0.9152542372881356

# %%
y_pred1=lr.predict(X_test)

# %%
print(classification_report(y_pred1,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      1.00      0.76         8
#            1       1.00      0.90      0.95        51
#
#     accuracy                           0.92        59
#    macro avg       0.81      0.95      0.86        59
# weighted avg       0.95      0.92      0.92        59

# %%
print(confusion_matrix(y_pred,y_test))
# Out:
# [[ 8  0]
#  [ 5 46]]

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt.score(X_train,y_train)
# Out:
# 1.0

# %%
dt.score(X_test,y_test)
# Out:
# 0.9322033898305084

# %%
y_pred2=dt.predict(X_test)

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      1.00      0.76         8
#            1       1.00      0.90      0.95        51
#
#     accuracy                           0.92        59
#    macro avg       0.81      0.95      0.86        59
# weighted avg       0.95      0.92      0.92        59

# %%
print(confusion_matrix(y_pred,y_test))
# Out:
# [[ 8  0]
#  [ 5 46]]

# %% [markdown]
# ## Hyperparameter Tuning

# %%
#RandomizedSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %%
#Number of trees in random forest
n_estimators=[int(x) for x in np.linspace(start=100,stop=1200,num=12)]
#Number of features to consider at every split
max_features=['auto','sqrt']
#Maximum number of level of the tree
max_depth=[int(x) for x in np.linspace(start=5,stop=30,num=6)]
#Minimum number of samples to split a node
min_samples_split=[1,2,5,10,15,100]
#Minimum number of samples required to leaf nodes
min_samples_leaf=[1,2,5,10]

# %%
#Create the random grid
random_grid={'n_estimators':n_estimators,'max_features':max_features,'max_depth':max_depth,'min_samples_split':min_samples_split,'min_samples_leaf':min_samples_leaf}

# %%
#Random Search of parameters, using 5 fold cross validation
#search across 100 different combinations
rf_random=RandomizedSearchCV(estimator=rf,param_distributions=random_grid,scoring='neg_mean_squared_error',n_iter=10,cv=5,verbose=2,random_state=42,n_jobs=1)

# %%
rf_random.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 1043, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 861, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 779, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 903, in fit
#     super().fit(
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 1043, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 861, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 779, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 903, in fit
#     super().fit(
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=1, n_estimators=700; total time=   0.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=1, n_estimators=700; total time=   0.1s
# C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 1043, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 861, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 779, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 903, in fit
#     super().fit(
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 1043, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 861, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 779, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 903, in fit
#     super().fit(
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=1, n_estimators=700; total time=   0.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=1, n_estimators=700; total time=   0.1s
# C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 1043, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 861, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 779, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 903, in fit
#     super().fit(
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=1, n_estimators=700; total time=   0.1s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=900; total time=   0.7s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=900; total time=   0.7s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=900; total time=   0.6s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=900; total time=   0.6s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=900; total time=   0.7s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=100, n_estimators=1100; total time=   0.8s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=100, n_estimators=1100; total time=   0.8s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=100, n_estimators=1100; total time=   0.8s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=100, n_estimators=1100; total time=   0.8s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=100, n_estimators=1100; total time=   0.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=300; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=300; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=300; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=300; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=300; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=400; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=400; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=400; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=400; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=400; total time=   0.2s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=900; total time=   0.6s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=900; total time=   0.6s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=900; total time=   0.6s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=900; total time=   0.6s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=900; total time=   0.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=700; total time=   0.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=700; total time=   0.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=700; total time=   0.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=700; total time=   0.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=700; total time=   0.5s
# C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 1043, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 861, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 779, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 903, in fit
#     super().fit(
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=1, n_estimators=1000; total time=   0.2s
# C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 1043, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 861, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 779, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 903, in fit
#     super().fit(
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=1, n_estimators=1000; total time=   0.1s
# C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 1043, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 861, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 779, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 903, in fit
#     super().fit(
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=1, n_estimators=1000; total time=   0.1s
# C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 1043, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 861, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 779, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 903, in fit
#     super().fit(
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=1, n_estimators=1000; total time=   0.2s
# C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 1043, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 861, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 779, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 903, in fit
#     super().fit(
#   File "C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=1, n_estimators=1000; total time=   0.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=1100; total time=   0.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=1100; total time=   0.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=1100; total time=   0.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=1100; total time=   0.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=1100; total time=   1.0s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.2s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.2s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.2s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.2s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.2s
# C:\Users\wwwka\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:922: UserWarning: One or more of the test scores are non-finite: [        nan -0.25740741 -0.25740741 -0.17671958 -0.16931217 -0.25740741
#  -0.16904762         nan -0.16904762 -0.13201058]
#   warnings.warn(
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=1,
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [1, 2, 5, 10, 15,
#                                                               100],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200]},
#                    random_state=42, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 300,
#  'min_samples_split': 2,
#  'min_samples_leaf': 2,
#  'max_features': 'auto',
#  'max_depth': 15}

# %%
prediction=rf_random.predict(X_test)

# %%
print(classification_report(prediction,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96        12
#            1       1.00      0.98      0.99        47
#
#     accuracy                           0.98        59
#    macro avg       0.96      0.99      0.97        59
# weighted avg       0.98      0.98      0.98        59

# %%
print(confusion_matrix(prediction,y_test))
# Out:
# [[12  0]
#  [ 1 46]]

# %% [markdown]
# # Save the model to reuse it again

# %%
import pickle
#Open a file to store the data
file=open('parkinsson_rf.pkl','wb')
#dump the information to the file
pickle.dump(rf_random,file)

# %%
model=open('parkinsson_rf.pkl','rb')

# %%
forest=pickle.load(model)

# %%
y_pred=forest.predict(X_test)

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96        12
#            1       1.00      0.98      0.99        47
#
#     accuracy                           0.98        59
#    macro avg       0.96      0.99      0.97        59
# weighted avg       0.98      0.98      0.98        59
